# %%
# Install MLRun if not installed, run this only once (restart the notebook after the install !!!)
# %pip install mlrun

# %%
import mlrun

project = mlrun.get_or_create_project("workflow-override", context="./", user_project=True)
# Out:
# > 2026-01-10 18:58:14,597 [info] Created and saved project: {"context":"./","from_template":null,"name":"workflow-override-admin","overwrite":false,"save":true}
# > 2026-01-10 18:58:14,599 [info] Project created successfully: {"project_name":"workflow-override-admin","stored_in_db":true}

# %%
project.build_config(
    base_image="mlrun/mlrun-kfp",
    requirements=["langchain==0.2.17", "openai==1.58.1", "langchain_community==0.2.19"],
    set_as_default = True
)

# Trigger the build for the project default image
project.build_image()

# %%
# OpenAI tokens:
import os

os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
os.environ["OPENAI_API_BASE"] = OPENAI_API_BASE

# %%
project.set_secrets(
    secrets={
        "OPENAI_API_KEY": OPENAI_API_KEY,
        "OPENAI_API_BASE": OPENAI_API_BASE,
    }
)

# %% [markdown]
# <a id="gs-tutorial-4-step-setting-up-project"></a>

# %% [markdown]
# **Function code**
#
# Run the following cell to generate the data prep file (or copy it manually):

# %%
# %%writefile src/data-prep.py

import pandas as pd
from sklearn.datasets import load_breast_cancer


def breast_cancer_generator():
    """
    A function that generates the breast cancer dataset
    """
    breast_cancer = load_breast_cancer()
    breast_cancer_dataset = pd.DataFrame(
        data=breast_cancer.data, columns=breast_cancer.feature_names
    )
    breast_cancer_labels = pd.DataFrame(data=breast_cancer.target, columns=["label"])
    breast_cancer_dataset = pd.concat(
        [breast_cancer_dataset, breast_cancer_labels], axis=1
    )

    return breast_cancer_dataset, "label"
# Out:
# Writing src/data-prep.py

# %% [markdown]
# **Register the function above in the project**

# %%
data_prep_func = project.set_function(
    "src/data-prep.py",
    name="data-prep",
    kind="job",
    image="mlrun/mlrun",
    handler="breast_cancer_generator",
)

structured_data_generator = project.set_function(
        func="hub://structured_data_generator",
        name="structured-data-generator",
        kind="job",
        # image=".mlrun-project-image-workflow-override-admin",#let it be default works?
)

# %%
data_prep_func.save()
structured_data_generator.save()
# Out:
# 'db://workflow-override-admin/structured-data-generator:latest'

# %%
project.set_function(f"db://{project.name}/data-prep", name="data-prep")
project.set_function(f"db://{project.name}/structured-data-generator", name="structured-data-generator")
project.set_source(f"db://{project.name}")

# %%
# Save the project in the db (and into the project.yaml file)
project.save()

# %%
# load the project in the current context dir
project = mlrun.load_project("./")

# %%
# %%writefile 'src/workflow.py'
#
# from kfp import dsl
# import mlrun
#
# # Create a Kubeflow Pipelines pipeline
# @dsl.pipeline(name="breast-cancer-demo")
# def pipeline(model_name="cancer-classifier"):
#
#     project = mlrun.get_current_project()
#
#     # Run the ingestion function with the new image and params
#     ingest = mlrun.run_function(
#         "data-prep",
#         name="get-data",
#         returns=["dataset", "label_column"],
#     )
#
#     client_data_generator_function = project.get_function(
#         "structured_data_generator"
#     )
#     client_data_run = project.run_function(
#         client_data_generator_function,
#         handler="generate_data",
#         name="client-data-generator",
#         params={
#             "amount": 2,
#             "model_name": "gpt-4",
#             "language": "en",
#             "fields": [
#                 f"first_name: in english, no special characters",
#                 f"last_name: in english, no special characters",
#                 "phone_number",
#                 "email",
#                 "client_id: no leading zeros, at least 8 digits long, only numbers, this is a primay key field for the database, avoid duplicates as much as possible",
#                 "client_city: Enter city, state in the US (e.g., Austin, TX), Not only Texas",
#                 "latitude: That correspond to the city",
#                 "longitude: That correspond to the city",
#             ],
#         },
#         returns=["clients: file"],
#     )
# Out:
# Overwriting src/workflow.py

# %%
project.set_workflow(name="main", workflow_path="./src/workflow.py", embed=True, )#image=".mlrun-project-image-tutorial-admin")
project.save()

# %% [markdown]
# <a id="gs-tutorial-4-step-register-workflow"></a>

# %% [markdown]
# **Run the workflow**

# %%
# Run the workflow
run_id = project.run(
    "main",
    arguments={"model_name": "cancer-classifier"},
    engine="remote",
    watch=True,
)
# Out:
# > 2026-01-10 19:13:22,253 [info] Submitting remote workflow: {"project_name":"workflow-override-admin","schedule":null,"workflow_engine":"kfp"}
# <div>Pipeline running (id=2309374f-4c82-4670-8803-ac1f69befbdc), <a href="https://mlrun-ui.default-tenant.app.cst-372.iguazio-cd0.com/mlprojects/workflow-override-admin/jobs/monitor-workflows/workflow/2309374f-4c82-4670-8803-ac1f69befbdc" target="_blank"><b>click here</b></a> to view the details in MLRun UI</div>
# > 2026-01-10 19:13:27,585 [info] Started run workflow workflow-override-admin-main with run id = '2309374f-4c82-4670-8803-ac1f69befbdc' by remote engine
# > 2026-01-10 19:13:27,585 [info] Waiting for pipeline run completion: {"project":"workflow-override-admin","run_id":"2309374f-4c82-4670-8803-ac1f69befbdc"}
# <h2>Run Results</h2><h3>[info] Workflow 2309374f-4c82-4670-8803-ac1f69befbdc finished, state=Succeeded</h3><br>click the hyper links below to see detailed results<br><table border="1" class="dataframe">
#   <thead>
# ...

# %%
# %%writefile src/test-image.py

import langchain
from langchain.chat_models import ChatOpenAI
def handler():
    print("-"*100)
    print(langchain.__version__)
    print("-"*100)
# Out:
# Writing src/test-image.py

# %%
test_image = project.set_function(name = "test-image",
                         func="src/test-image.py",
                         handler = "handler",
                         kind = "job"
                        )

# %%
project.run_function(test_image, local=False)
# Out:
# > 2026-01-10 19:06:09,733 [info] Storing function: {"db":"http://mlrun-api:8080","name":"test-image-handler","uid":"889d4dd4ed8e4b52855778b72471427d"}
# > 2026-01-10 19:06:09,987 [info] Job is running in the background, pod: test-image-handler-6r7qj
# Importing chat models from langchain is deprecated. Importing from langchain will no longer be supported as of langchain==0.2.0. Please import from langchain-community instead:
#
# `from langchain_community.chat_models import ChatOpenAI`.
#
# To install langchain-community run `pip install -U langchain-community`.
# ----------------------------------------------------------------------------------------------------
# 0.2.17
# ----------------------------------------------------------------------------------------------------
# ...

# %%
test_image.save()
# Out:
# 'db://workflow-override-admin/test-image:latest'

# %% [markdown]
# ### without this line, it will not work

# %%
project.set_function(f"db://{project.name}/test-image", name="test-image")

# %%
# %%writefile 'src/workflow-image.py'
#
# from kfp import dsl
# import mlrun
#
# # Create a Kubeflow Pipelines pipeline
# @dsl.pipeline(name="test-image-in-workflow")
# def pipeline():
#
#     project = mlrun.get_current_project()
#
#     # Run the ingestion function
#     f = project.get_function("test-image")
#     f_run = project.run_function(f)
# Out:
# Overwriting src/workflow-image.py

# %%
project.set_workflow(name="test-image-in-workflow", workflow_path="./src/workflow-image.py", embed=True, )#image=".mlrun-project-image-tutorial-admin")
project.save()

# %%
# Run the workflow
run_id = project.run(
    "test-image-in-workflow",
    engine="remote",
    watch=True,
)
# Out:
# > 2026-01-10 19:06:54,880 [info] Submitting remote workflow: {"project_name":"workflow-override-admin","schedule":null,"workflow_engine":"kfp"}
# <div>Pipeline running (id=8e1ad36b-0123-492c-aab3-ea347c7442ce), <a href="https://mlrun-ui.default-tenant.app.cst-372.iguazio-cd0.com/mlprojects/workflow-override-admin/jobs/monitor-workflows/workflow/8e1ad36b-0123-492c-aab3-ea347c7442ce" target="_blank"><b>click here</b></a> to view the details in MLRun UI</div>
# > 2026-01-10 19:07:00,215 [info] Started run workflow workflow-override-admin-test-image-in-workflow with run id = '8e1ad36b-0123-492c-aab3-ea347c7442ce' by remote engine
# > 2026-01-10 19:07:00,216 [info] Waiting for pipeline run completion: {"project":"workflow-override-admin","run_id":"8e1ad36b-0123-492c-aab3-ea347c7442ce"}
# <h2>Run Results</h2><h3>[info] Workflow 8e1ad36b-0123-492c-aab3-ea347c7442ce finished, state=Succeeded</h3><br>click the hyper links below to see detailed results<br><table border="1" class="dataframe">
# ...
